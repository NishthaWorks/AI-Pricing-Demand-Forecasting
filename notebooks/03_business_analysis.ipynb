# %% [markdown]
# # Business Analysis
#
# ## Objective
#
# The objective of this notebook is to answer key business questions that retail executives face before making pricing and inventory decisions.
#
# Instead of only visualizing data, we aim to generate actionable business insights that can improve profitability, inventory planning, and customer demand forecasting.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load Dataset
df = pd.read_csv("../data/raw/retail_store_inventory (1).csv")

# Revenue Calculation
df["Revenue"] = df["Units Sold"] * df["Price"]

# Revenue by Category
category_revenue = (
    df.groupby("Category")["Revenue"]
      .sum()
      .sort_values(ascending=False)
)

category_revenue
# Out:
# Category
# Furniture      1.115118e+08
# Groceries      1.109845e+08
# Clothing       1.096510e+08
# Toys           1.096424e+08
# Electronics    1.084391e+08
# Name: Revenue, dtype: float64

# %%
plt.figure(figsize=(8,5))

category_revenue.plot(kind="bar")

plt.title("Revenue by Category")
plt.xlabel("Category")
plt.ylabel("Revenue")

plt.show()

# %% [markdown]
# ## Business Insight
#
# Revenue is a better performance indicator than units sold because it reflects the financial contribution of each category.
#
# A category may sell fewer units but generate significantly higher revenue due to premium pricing.
#
# Managers should prioritize high-revenue categories for pricing optimization and inventory planning.

# %%
region_revenue = (
    df.groupby("Region")["Revenue"]
      .sum()
      .sort_values(ascending=False)
)

region_revenue
# Out:
# Region
# East     1.387121e+08
# South    1.384836e+08
# North    1.372553e+08
# West     1.357780e+08
# Name: Revenue, dtype: float64

# %%
plt.figure(figsize=(8,5))

region_revenue.plot(kind="bar")

plt.title("Revenue by Region")

plt.show()

# %%
discount_category = (
    df.groupby("Category")["Discount"]
      .mean()
      .sort_values(ascending=False)
)

discount_category
# Out:
# Category
# Electronics    10.040975
# Furniture      10.031635
# Clothing       10.005812
# Toys            9.993854
# Groceries       9.975361
# Name: Discount, dtype: float64

# %%
plt.figure(figsize=(8,5))

discount_category.plot(kind="bar")

plt.title("Average Discount by Category")

plt.show()

# %%
plt.figure(figsize=(8,6))

plt.scatter(
    df["Discount"],
    df["Units Sold"],
    alpha=0.3
)

plt.xlabel("Discount")
plt.ylabel("Units Sold")
plt.title("Discount vs Units Sold")

plt.show()
